# %%
from dotenv import load_dotenv
import os
import requests
import json
import pandas as pd
import quandl
import matplotlib

# %matplotlib inline

# %%
load_dotenv()
# Out:
# True

# %%
quandl.ApiConfig.api_key = os.getenv('QUANDL_API_KEY')

# %%
data = quandl.get_table('ZILLOW/DATA', indicator_id='Z1BR', region_id='268020')
data
# Out:
#      indicator_id region_id       date      value
# None
# 0            Z1BR    268020 2020-12-31  1209880.0
# 1            Z1BR    268020 2020-11-30  1221959.0
# 2            Z1BR    268020 2020-10-31  1232359.0
# 3            Z1BR    268020 2020-09-30  1249561.0
# 4            Z1BR    268020 2020-08-31  1270730.0
# 5            Z1BR    268020 2020-07-31  1268802.0
# 6            Z1BR    268020 2020-06-30  1289970.0
# 7            Z1BR    268020 2020-05-31  1336873.0
# 8            Z1BR    268020 2020-04-30  1356495.0
# 9            Z1BR    268020 2020-03-31  1362229.0
# 10           Z1BR    268020 2020-02-29  1360273.0
# 11           Z1BR    268020 2020-01-31  1346709.0
# 12           Z1BR    268020 2019-12-31  1331776.0
# 13           Z1BR    268020 2019-11-30  1318294.0
# 14           Z1BR    268020 2019-10-31  1312200.0
# 15           Z1BR    268020 2019-09-30  1310071.0
# 16           Z1BR    268020 2019-08-31  1315358.0
# 17           Z1BR    268020 2019-07-31  1319143.0
# ...
