# %%
from dotenv import load_dotenv
import os
import requests
import json
import pandas as pd
import quandl

# %%
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv('QUANDL_API_KEY')

# %%
quandl.ApiConfig.api_key = api_key
regions_data = quandl.get_table('ZILLOW/REGIONS', paginate = True)
regions_data
# Out:
#       region_id region_type                                             region
# None
# 0         99999         zip     98847; WA; Wenatchee; Chelan County; Peshastin
# 1         99998         zip                98846; WA; Okanogan County; Pateros
# 2         99997         zip    98845; WA; Wenatchee; Douglas County; Palisades
# 3         99996         zip               98844; WA; Okanogan County; Oroville
# 4         99995         zip       98843; WA; Wenatchee; Douglas County; Orondo
# 5         99994         zip                   98841; WA; Okanogan County; Omak
# 6         99993         zip               98840; WA; Okanogan County; Okanogan
# 7         99992         zip                98837; WA; Moses Lake; Grant County
# 8         99991         zip                98836; WA; Wenatchee; Chelan County
# 9         99990         zip                 98834; WA; Okanogan County; Methow
# 10         9999        city  Carrsville; VA; Virginia Beach-Norfolk-Newport...
# ...

# %%
regions_data.to_csv(r'zillow_regions_data.csv', index = False)
